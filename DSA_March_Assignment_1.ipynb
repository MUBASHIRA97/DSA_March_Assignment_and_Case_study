# %% [markdown]
# # Import numpy,pandas,matplotlib and seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read the dataset in excel format to python environment

# %%
data = pd.read_excel(r'C:\Users\USER\Downloads\iris.xls')

# %% [markdown]
# # Display columns in the iris dataset

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # Calculate the mean of each column of the iris dataset

# %%
data.mean()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10080\531903386.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # Check for the null values present in the dataset

# %%
# Finding missing values using isnull() function.If there is a data missing,it will display True else False

data.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
# Summarize missing values present in dataset

data.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# This means there is no missing values present in the iris dataset

# %% [markdown]
# # Perform visualizations using the dataset

# %%
# Histogram of Sepal Length

plt.hist(data['SL'],bins=20,color='green')
plt.xlabel('Sepal Length in cm')
plt.ylabel('Count')
plt.title('Sepal Length')
plt.show()

# %%
# Histogram of Sepal Width

plt.hist(data['SW'],bins=20,color='red')
plt.xlabel('Sepal Width in cm')
plt.ylabel('Count')
plt.title('Sepal Width')
plt.show()

# %%
# Countplot of Petal length

plt.figure(figsize=(18,8))
sns.countplot(x=data.PL)
plt.title('Petal Length')
plt.show()

# %%
# Countplot of Sepal length

plt.figure(figsize=(18,8))
sns.countplot(x=data.SL)
plt.title('Sepal Length')
plt.show()

# %%
# Boxplot of Sepal Width

plt.boxplot(data['SW'])
plt.xlabel('Sepal Width in cm')
plt.ylabel('Count')
plt.title('Sepal Width')
plt.show()

# %%
# Boxplot of Sepal Length


plt.boxplot(data['SL'])
plt.xlabel('Sepal Length in cm')
plt.ylabel('Count')
plt.title('Sepal Length')
plt.show()

# %%
# Boxplot of Petal Length


plt.boxplot(data['PL'])
plt.xlabel('Petal Length in cm')
plt.ylabel('Count')
plt.title('Petal Length')
plt.show()

# %%
# Boxplot of Petal Width


plt.boxplot(data['PW'])
plt.xlabel('Petal Width in cm')
plt.ylabel('Count')
plt.title('Petal Width')
plt.show()

# %%
# Scatter Plot  of sepal width and classification

plt.scatter(data['SW'],data['Classification'])
plt.xlabel('Sepal Width in cm')
plt.ylabel('Count')
plt.title('Sepal Width')
plt.show()

# %%
# Scatter Plot of sepal length and classification

plt.scatter(data['SL'],data['Classification'])
plt.xlabel('Sepal Length in cm')
plt.ylabel('Count')
plt.title('Sepal Length')
plt.show()

# %%
# Scatter plot of sepal length and sepal width

plt.scatter(data['SL'],data['SW'])
plt.xlabel('Sepal Length in cm')
plt.ylabel('Sepal Width in cm')
plt.title('Relation between Sepal Length & Sepal Width')
plt.show()
